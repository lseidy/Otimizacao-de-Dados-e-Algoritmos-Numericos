# %%
import math
import numpy as np

# %%
f0 = 1
f1 = 3
f_x = lambda x: math.pow(math.e,x)

# %%
def metTrapezio(f0, f1):
  Trap = (f1-f0) * (f0 + f1)/2
  return Trap

# %%
metTrapezio(f0,f1)
# Out:
# 4.0

# %%
def metTrapezioM(f,a,b,n):
  h = (b-a)/n
  for i in range(n):
    if i == 0:
       sum = f(0)
    else:
      sum  = sum + (2 *f(((a + h*i)))) 
  sum = sum + f(h*n)
  Trapm = (h/2)*sum

  return Trapm

# %%
metTrapezioM(f_x,1,2,10)
# Out:
# 4.355213128852902
